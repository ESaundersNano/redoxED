# %% [markdown]
# # Testing Loading Data

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

from redoxed.data_loading.data_loaders import LoaderFactory, BiologicLoader, CSVLoader
from redoxed.plots.eis_plot import EISPlot

# %%
fpath=r"C:\Users\es758\OneDrive - University of Cambridge\PhD\Results\Electrochemistry\Full Cell 3\2025.03.21 FB1_FCN_KCl_E620K_GFDB0_B3lasercen\5_50ml_50soc_20mM_FCN_33rpm_laseredge_6Nm_C02.mpr"
LoaderFactory.get_loader(fpath).load_data(fpath=fpath)
# Out:
# ECData(label=C:\Users\es758\OneDrive - University of Cambridge\PhD\Results\Electrochemistry\Full Cell 3\2025.03.21 FB1_FCN_KCl_E620K_GFDB0_B3lasercen\5_50ml_50soc_20mM_FCN_33rpm_laseredge_6Nm_C02.mpr)

# %%
data = BiologicLoader().load_data(fpath=fpath)
data.df
# Out:
#        freq/Hz  Re(Z)/Ohm  -Im(Z)/Ohm   |Z|/Ohm  Phase(Z)/deg       time/s  \
# 0     0.000000   0.000000   -0.000000  0.000000      0.000000     1.273600
# 1     0.000000   0.000000   -0.000000  0.000000      0.000000     2.273600
# 2     0.000000   0.000000   -0.000000  0.000000      0.000000     3.273600
# 3     0.000000   0.000000   -0.000000  0.000000      0.000000     4.273600
# 4     0.000000   0.000000   -0.000000  0.000000      0.000000     5.273600
# ...        ...        ...         ...       ...           ...          ...
# 1236  0.125907   0.508321    0.198372  0.545657    -21.318239  7876.994974
# 1237  0.112088   0.530362    0.208901  0.570021    -21.498629  7886.841975
# 1238  0.099904   0.551042    0.217626  0.592460    -21.550817  7897.887975
# 1239  0.089005   0.572890    0.221128  0.614085    -21.105927  7910.284976
# 1240  0.079421   0.598498    0.221391  0.638133    -20.299971  7924.174976
#
#        <Ewe>/V    <I>/mA      Cs/µF         Cp/µF  cycle number   |Ewe|/V  \
# 0    -0.000004  0.007581        0.0  0.000000e+00           1.0  0.000000
# 1    -0.000003  0.009482        0.0  0.000000e+00           1.0  0.000000
# 2    -0.000006  0.005720        0.0  0.000000e+00           1.0  0.000000
# 3    -0.000007  0.005900        0.0  0.000000e+00           1.0  0.000000
# 4    -0.000010  0.005761        0.0  0.000000e+00           1.0  0.000000
# ...        ...       ...        ...           ...           ...       ...
# 1236 -0.000233 -0.006983  6372219.5  8.421972e+05           8.0  0.027808
# 1237 -0.000190 -0.007126  6797095.5  9.128962e+05           8.0  0.029050
# 1238 -0.000065 -0.007130  7320250.0  9.877112e+05           8.0  0.030193
# 1239  0.000045 -0.007063  8086531.0  1.048558e+06           8.0  0.031295
# 1240  0.000079 -0.006911  9051582.0  1.089485e+06           8.0  0.032521
#
#          |I|/A  Ns  I Range  (Q-Qo)/mA.h
# 0     0.000000   0       10     0.000002
# 1     0.000000   0       10     0.000004
# 2     0.000000   0       10     0.000005
# 3     0.000000   0       10     0.000007
# 4     0.000000   0       10     0.000008
# ...        ...  ..      ...          ...
# 1236  0.050963   0       10    -0.639230
# 1237  0.050963   0       10    -0.636110
# 1238  0.050963   0       10    -0.641735
# 1239  0.050963   0       10    -0.655665
# 1240  0.050963   0       10    -0.673367
#
# [1241 rows x 16 columns]
